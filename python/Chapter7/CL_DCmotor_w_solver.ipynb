# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

def DC_motor_w(t, x):
    # Placeholder function for the DC motor dynamics
    # Replace this with the actual function defining the dynamics
    # Example:
    # dxdt = [x[1], -0.1 * x[1] + np.sin(x[0]), x[3], -0.1 * x[3] + np.cos(x[2])]
    dxdt = [0, 0, 0, 0]  # Dummy dynamics, replace with actual
    return dxdt

# Initial conditions
x0 = [0, 0, 0, 0.01]

# Time span
tspan = (0, 3)

# Solve the ODE
sol = solve_ivp(DC_motor_w, tspan, x0, method='RK45', max_step=1e-2, vectorized=True)

# Plot the results
plt.figure()
plt.plot(sol.t, sol.y[0] * 180 / np.pi, 'k', linewidth=2)
plt.grid(True)
plt.xlabel('Time (sec)')
plt.ylabel('Angular displacement (degrees)')
# plt.legend(['$\\theta$ (degrees)'])
plt.show()
